# %%
import json

# %%
fd=open("best_results_accuracy_STree.json")
fo=open("best_results_accuracy_ODTE.json", "w")
data=json.load(fd)

# %%
data['balance-scale'][1]
# Out:
# {'C': 10000.0,
#  'gamma': 0.1,
#  'kernel': 'rbf',
#  'max_iter': 10000.0,
#  'multiclass_strategy': 'ovr'}

# %%
for key, value in data.items():
    value[0]=0.0
    value[2]="-program made-"
    value[1] = {"n_jobs": 10, "n_estimators": 100, "be_hyperparams": value[1]}
json.dump(data, fo)
fd.close()
fo.close()

# %%
data
# Out:
# {'balance-scale': [0.0,
#   {'n_jobs': 10,
#    'n_estimators': 100,
#    'be_hyperparams': {'C': 10000.0,
#     'gamma': 0.1,
#     'kernel': 'rbf',
#     'max_iter': 10000.0,
#     'multiclass_strategy': 'ovr'}},
#   '-program made-'],
#  'balloons': [0.0,
#   {'n_jobs': 10,
#    'n_estimators': 100,
#    'be_hyperparams': {'C': 7,
#     'gamma': 0.1,
#     'kernel': 'rbf',
#     'max_iter': 10000.0,
#     'multiclass_strategy': 'ovr'}},
#   '-program made-'],
#  'breast-cancer-wisc-diag': [0.0,
#   {'n_jobs': 10,
#    'n_estimators': 100,
#    'be_hyperparams': {'C': 0.2,
#     'max_iter': 10000.0,
#     'kernel': 'liblinear',
#     'multiclass_strategy': 'ovr'}},
#   '-program made-'],
#  'breast-cancer-wisc-prog': [0.0,
#   {'n_jobs': 10,
#    'n_estimators': 100,
#    'be_hyperparams': {'C': 0.2,
#     'max_iter': 10000.0,
#     'kernel': 'liblinear',
#     'multiclass_strategy': 'ovr'}},
#   '-program made-'],
#  'breast-cancer-wisc': [0.0,
#   {'n_jobs': 10,
# ...
